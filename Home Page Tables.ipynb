# %%
import pandas as pd

# %%
weather_data = pd.read_csv("weather_data_update.csv")
weather_data.head()
# Out:
#    Unnamed: 0  city_id         city_name  city_lat  city_lon country  \
# 0           0  1138958             Kabul   34.5260   69.1776      AF
# 1           1  3183875            Tirana   41.3275   19.8189      AL
# 2           2  4335045           Algiers   29.9413  -90.0376      US
# 3           3  3041563  Andorra la Vella   42.5069    1.5212      FR
# 4           4  2240449            Luanda   -8.8272   13.2437      AO
#
#    city_time    date_one_time_one  date_one_time_one_temp  \
# 0      16200  2020-01-07 22:00:00                   17.20
# 1       3600  2020-01-07 22:00:00                   25.84
# 2     -21600  2020-01-07 22:00:00                   51.96
# 3       3600  2020-01-07 22:00:00                   33.91
# 4       3600  2020-01-07 22:00:00                   78.69
#
#    date_one_time_one_temp_min  ...   date_five_time_six  \
# 0                        7.97  ...  2020-01-08 13:00:00
# 1                       25.84  ...  2020-01-08 13:00:00
# ...

# %%
list(weather_data.columns)
# Out:
# ['Unnamed: 0',
#  'city_id',
#  'city_name',
#  'city_lat',
#  'city_lon',
#  'country',
#  'city_time',
#  'date_one_time_one',
#  'date_one_time_one_temp',
#  'date_one_time_one_temp_min',
#  'date_one_time_one_temp_max',
#  'date_one_time_one_pressure',
#  'date_one_time_one_sea_level',
#  'date_one_time_one_grnd_level',
#  'date_one_time_one_humidity',
#  'date_one_time_one_wind_speed',
#  'date_one_time_one_direction',
#  'date_one_time_two',
#  'date_one_time_two_temp',
#  'date_one_time_two_temp_min',
#  'date_one_time_two_temp_max',
#  'date_one_time_two_pressure',
#  'date_one_time_two_sea_level',
#  'date_one_time_two_grnd_level',
#  'date_one_time_two_humidity',
#  'date_one_time_two_wind_speed',
#  'date_one_time_two_direction',
#  'date_one_time_three',
#  'date_one_time_three_temp',
#  'date_one_time_three_temp_min',
#  'date_one_time_three_temp_max',
#  'date_one_time_three_pressure',
#  'date_one_time_three_sea_level',
#  'date_one_time_three_grnd_level',
# ...

# %%
weather_tables_df = weather_data[['city_name', 'country', 'city_time', 
                                  'date_one_time_one_temp_min', 'date_one_time_one_temp_max',
                                  'date_two_time_one_temp_min', 'date_two_time_one_temp_max', 
                                 'date_three_time_one_temp_min', 'date_three_time_one_temp_max', 
                                  'date_four_time_one_temp_min', 'date_four_time_one_temp_max', 
                                 'date_five_time_one_temp_min', 'date_five_time_one_temp_max' ]]
                                  #'five_day_min_avg', 'five_day_max_avg', 'total_avg_all__five_days' 
weather_tables_df.head()
# Out:
#           city_name country  city_time  date_one_time_one_temp_min  \
# 0             Kabul      AF      16200                        7.97
# 1            Tirana      AL       3600                       25.84
# 2           Algiers      US     -21600                       51.96
# 3  Andorra la Vella      FR       3600                       33.91
# 4            Luanda      AO       3600                       78.69
#
#    date_one_time_one_temp_max  date_two_time_one_temp_min  \
# 0                       17.20                        7.97
# 1                       29.61                       25.84
# 2                       52.79                       51.96
# 3                       34.81                       33.91
# 4                       78.87                       78.69
#
#    date_two_time_one_temp_max  date_three_time_one_temp_min  \
# 0                       17.20                          7.97
# 1                       29.61                         25.84
# ...

# %%
weather_tables_df['five_day_min_avg'] = ""
weather_tables_df['five_day_max_avg'] = ""
weather_tables_df['total_avg_all__five_days'] = ""

weather_tables_df.head()
# Out:
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
weather_tables_df['five_day_min_avg'] = ((weather_tables_df['date_one_time_one_temp_min'] + weather_tables_df['date_two_time_one_temp_min'] + weather_tables_df['date_three_time_one_temp_min'] + weather_tables_df['date_four_time_one_temp_min'] + weather_tables_df['date_five_time_one_temp_min'])/5)
weather_tables_df.head()
# Out:
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           city_name country  city_time  date_one_time_one_temp_min  \
# 0             Kabul      AF      16200                        7.97
# 1            Tirana      AL       3600                       25.84
# 2           Algiers      US     -21600                       51.96
# 3  Andorra la Vella      FR       3600                       33.91
# 4            Luanda      AO       3600                       78.69
#
#    date_one_time_one_temp_max  date_two_time_one_temp_min  \
# 0                       17.20                        7.97
# ...

# %%
weather_tables_df['five_day_max_avg'] = ((weather_tables_df['date_one_time_one_temp_max'] + weather_tables_df['date_two_time_one_temp_max'] + weather_tables_df['date_three_time_one_temp_max'] + weather_tables_df['date_four_time_one_temp_max'] + weather_tables_df['date_five_time_one_temp_max'])/5)
weather_tables_df.head()
# Out:
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           city_name country  city_time  date_one_time_one_temp_min  \
# 0             Kabul      AF      16200                        7.97
# 1            Tirana      AL       3600                       25.84
# 2           Algiers      US     -21600                       51.96
# 3  Andorra la Vella      FR       3600                       33.91
# 4            Luanda      AO       3600                       78.69
#
#    date_one_time_one_temp_max  date_two_time_one_temp_min  \
# 0                       17.20                        7.97
# ...

# %%
weather_tables_df['total_avg_all__five_days'] = ((weather_tables_df['five_day_max_avg'] + weather_tables_df['five_day_min_avg'])/2)
weather_tables_df.head()
# Out:
# C:\Users\Shaheda Choudhury\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           city_name country  city_time  date_one_time_one_temp_min  \
# 0             Kabul      AF      16200                        7.97
# 1            Tirana      AL       3600                       25.84
# 2           Algiers      US     -21600                       51.96
# 3  Andorra la Vella      FR       3600                       33.91
# 4            Luanda      AO       3600                       78.69
#
#    date_one_time_one_temp_max  date_two_time_one_temp_min  \
# 0                       17.20                        7.97
# ...

# %%
web_tables_df = weather_tables_df[['city_name', 'country', 'city_time','five_day_min_avg', 'five_day_max_avg', 'total_avg_all__five_days' ]]
web_tables_df.head()
# Out:
#           city_name country  city_time  five_day_min_avg  five_day_max_avg  \
# 0             Kabul      AF      16200              7.97             17.20
# 1            Tirana      AL       3600             25.84             29.61
# 2           Algiers      US     -21600             51.96             52.79
# 3  Andorra la Vella      FR       3600             33.91             34.81
# 4            Luanda      AO       3600             78.69             78.87
#
#    total_avg_all__five_days
# 0                    12.585
# 1                    27.725
# 2                    52.375
# 3                    34.360
# 4                    78.780

# %%
#web_tables_df['temp_range'] = ""
#web_tables_df.head()

# %%
'''for r in web_tables_df['total_avg_all__five_days']: 
    if r <= -20:
        web_tables_df[temp_range] = '-20oF to 0oF'
        continue

web_tables_df.head()'''
# Out:
# "for r in web_tables_df['total_avg_all__five_days']: \n    if r <= -20:\n        web_tables_df[temp_range] = '-20oF to 0oF'\n        continue\n\nweb_tables_df.head()"

# %%
web_tables_df.to_csv("web_tables.csv")
